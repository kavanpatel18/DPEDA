# %% [markdown]
# # Create Synthesized Datasets

# %%
#Faker library generates fake data for you
# !pip install faker
# Out:
# Requirement already satisfied: faker in /usr/local/lib/python3.11/dist-packages (37.4.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from faker) (2025.2)

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd #for data manipulation and analysis
import uuid #Generates unique ids
import random #Generates random numbers
from faker import Faker

# %% [markdown]
# Creating variables

# %%
#Number of rows or users to create
num_users=100

# %% [markdown]
# Adding feature list

# %%
#Making a list of 5 features
features = [
    "id",
    "gender",
    "subscriber",
    "name",
    "rating"
]

#Creating a dataframe for these features
df = pd.DataFrame(columns=features)
df
# Out:
# Empty DataFrame
# Columns: [id, gender, subscriber, name, rating]
# Index: []

# %% [markdown]
# ## Generate unique identifiers

# %% [markdown]
# UUID is a great library to generate unique IDS for each user because of its astronomically low chance of duplicating an ID.

# %%
df['id'] = [uuid.uuid4().node for i in range(num_users)]
df
#populates the 'id' column of DataFrame df with unique identifiers
# Out:
#                  id gender subscriber name rating
# 0   266855871871661    NaN        NaN  NaN    NaN
# 1   266208876814763    NaN        NaN  NaN    NaN
# 2    94781789620679    NaN        NaN  NaN    NaN
# 3   147188407183592    NaN        NaN  NaN    NaN
# 4   192158026215852    NaN        NaN  NaN    NaN
# ..              ...    ...        ...  ...    ...
# 95  146967315342308    NaN        NaN  NaN    NaN
# 96  261205810492539    NaN        NaN  NaN    NaN
# 97   84028108729798    NaN        NaN  NaN    NaN
# 98  181391708896621    NaN        NaN  NaN    NaN
# 99    9998748358153    NaN        NaN  NaN    NaN
#
# [100 rows x 5 columns]

# %% [markdown]
# Checking if all IDs are unique

# %%
print(df['id'].nunique()==num_users)
# Out:
# True

# %% [markdown]
# ## Generating Gender column

# %%
genders = ["male","female","na"]

df['gender'] = random.choices(genders, weights=(45,45,10),k=num_users)
df

#assigns a gender to each of the 100 users in your DataFrame, with a higher probability for "male" and "female" compared to "na".
# Out:
#                  id  gender subscriber name rating
# 0   266855871871661    male        NaN  NaN    NaN
# 1   266208876814763  female        NaN  NaN    NaN
# 2    94781789620679  female        NaN  NaN    NaN
# 3   147188407183592  female        NaN  NaN    NaN
# 4   192158026215852    male        NaN  NaN    NaN
# ..              ...     ...        ...  ...    ...
# 95  146967315342308    male        NaN  NaN    NaN
# 96  261205810492539    male        NaN  NaN    NaN
# 97   84028108729798    male        NaN  NaN    NaN
# 98  181391708896621  female        NaN  NaN    NaN
# 99    9998748358153    male        NaN  NaN    NaN
#
# [100 rows x 5 columns]

# %%
#Getting count of different genders in the list
df.gender.value_counts()
# Out:
# gender
# male      44
# female    43
# na        13
# Name: count, dtype: int64

# %% [markdown]
# ## Generating Subscriber values

# %% [markdown]
# For this attribute, the choices can be randomly selected between True or False.

# %%
choice = [True, False]

df['subscriber'] = random.choices(choice, k=num_users)
df
# Out:
#                  id  gender  subscriber name rating
# 0   266855871871661    male       False  NaN    NaN
# 1   266208876814763  female        True  NaN    NaN
# 2    94781789620679  female        True  NaN    NaN
# 3   147188407183592  female       False  NaN    NaN
# 4   192158026215852    male       False  NaN    NaN
# ..              ...     ...         ...  ...    ...
# 95  146967315342308    male        True  NaN    NaN
# 96  261205810492539    male        True  NaN    NaN
# 97   84028108729798    male        True  NaN    NaN
# 98  181391708896621  female        True  NaN    NaN
# 99    9998748358153    male        True  NaN    NaN
#
# [100 rows x 5 columns]

# %%
df.subscriber.value_counts()
# Out:
# subscriber
# False    50
# True     50
# Name: count, dtype: int64

# %% [markdown]
# ## Generating name values`

# %%
#Instantiating faker
faker = Faker(locale="FR_FR")
def name_gen(gender):
    if gender == "male":
        return faker.name_male()
    elif gender == 'female':
        return faker.name_female()
    else:
        return faker.name()

#returns a gender-appropriate fake name using the Faker library

# %%
#Generating names for each user
df['name'] = [name_gen(i) for i in df['gender']]
df
# Out:
#                  id  gender  subscriber                    name rating
# 0   266855871871661    male       False            Hugues Boyer    NaN
# 1   266208876814763  female        True        Adélaïde du Ruiz    NaN
# 2    94781789620679  female        True      Jacqueline Raymond    NaN
# 3   147188407183592  female       False       Christiane Albert    NaN
# 4   192158026215852    male       False              Émile Noël    NaN
# ..              ...     ...         ...                     ...    ...
# 95  146967315342308    male        True           Jules Michaud    NaN
# 96  261205810492539    male        True         Georges Laporte    NaN
# 97   84028108729798    male        True  Emmanuel-Pierre Vallet    NaN
# 98  181391708896621  female        True        Juliette Guillon    NaN
# 99    9998748358153    male        True            Louis Martel    NaN
#
# [100 rows x 5 columns]

# %%
df.name.value_counts()
# Out:
# name
# Hugues Boyer              1
# Adélaïde du Ruiz          1
# Jacqueline Raymond        1
# Christiane Albert         1
# Émile Noël                1
#                          ..
# Jules Michaud             1
# Georges Laporte           1
# Emmanuel-Pierre Vallet    1
# Juliette Guillon          1
# Louis Martel              1
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# ## Generate Rating values
# We can choose to skew the distribution of 1 to 5 towards the extremes to reflect the tendancies of users being more absolute with their ratings

# %%
ratings = [1,2,3,4,5] #Avalaible ratings list

# %%
#Weighted ratings with a skew towards the ends
df['rating'] = random.choices(ratings, weights=(5,10,10,10,5), k=num_users)
df
# Out:
#                  id  gender  subscriber                    name  rating
# 0   266855871871661    male       False            Hugues Boyer       3
# 1   266208876814763  female        True        Adélaïde du Ruiz       4
# 2    94781789620679  female        True      Jacqueline Raymond       2
# 3   147188407183592  female       False       Christiane Albert       2
# 4   192158026215852    male       False              Émile Noël       4
# ..              ...     ...         ...                     ...     ...
# 95  146967315342308    male        True           Jules Michaud       1
# 96  261205810492539    male        True         Georges Laporte       5
# 97   84028108729798    male        True  Emmanuel-Pierre Vallet       3
# 98  181391708896621  female        True        Juliette Guillon       1
# 99    9998748358153    male        True            Louis Martel       2
#
# [100 rows x 5 columns]

# %%
df.rating.value_counts() #Getting count of ratings
# Out:
# rating
# 2    28
# 4    24
# 3    19
# 5    15
# 1    14
# Name: count, dtype: int64

# %% [markdown]
# # Convert dataframe to dataset
# Export your generated synthetic data into a file format that can be easily shared or used for further analysis in other tools or programs.

# %%
df.to_csv('dataset1.csv')

# %%
#Viewing the saved csv file
csv_df = pd.read_csv('dataset1.csv', index_col=0)
csv_df
# Out:
#                  id  gender  subscriber                    name  rating
# 0   266855871871661    male       False            Hugues Boyer       3
# 1   266208876814763  female        True        Adélaïde du Ruiz       4
# 2    94781789620679  female        True      Jacqueline Raymond       2
# 3   147188407183592  female       False       Christiane Albert       2
# 4   192158026215852    male       False              Émile Noël       4
# ..              ...     ...         ...                     ...     ...
# 95  146967315342308    male        True           Jules Michaud       1
# 96  261205810492539    male        True         Georges Laporte       5
# 97   84028108729798    male        True  Emmanuel-Pierre Vallet       3
# 98  181391708896621  female        True        Juliette Guillon       1
# 99    9998748358153    male        True            Louis Martel       2
#
# [100 rows x 5 columns]
